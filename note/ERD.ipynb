# %% [markdown]
# ```mermaid
# erDiagram
#     BookCategory {
#         int categ_id PK
#         string(100) categ_name
#         int parent_categ_id
#         date reg_date
#         int use_yn
#         int nav_seq
#     }
#     Book {
#         int book_id PK
#         string(300) book_title
#         string(300) book_subtitle
#         int book_category_ID FK
#         string(100) publisher
#         string(3000) summary
#         date pub_date
#         date reg_date
#     }
#     BookStock {
#         int book_id PK
#         int stock_seq PK
#         float stock_price
#         int book_status  "1 - 대출가능, 2 - 대출중, 3 - 수선중, 4 - 폐기"
#         string(50) location
#         date stock_date
#         date status_date
#     }
#     Member {
#         string(20) member_id PK
#         string(100) member_name
#         string(100) region
#         string(100) address1
#         string(100) address2
#         string(50) mobile
#         string(128) pwd
#         int birth_year
#         date join_date
#         int quit_yn
#         int gender  "1-남성, 2-여성"
#     }
#     Rent {
#         int book_id PK,FK
#         int stock_seq PK,FK
#         string(20) member_id PK,FK
#         date rent_date
#         date return_date
#     }
#     Rating {
#         int book_id PK, FK
#         string(20) member_id PK, FK
#         int rating
#         date rate_date
#     }
#     Tag {
#         int tag_id PK
#         string(200) keyword
#         date reg_date
#     }
#     BookTag {
#         int book_id PK, FK
#         int tag_id PK, FK
#         date tag_date
#     }
#     BookDetail {
#         int book_id PK, FK
#         string(3000) description
#         string(3000) contents
#         date reg_date
#     }
#     Review {
#         string(20) member_id PK, FK
#         int book_id PK, FK
#         string(3000) contents
#         date reg_date
#     }
#     BookStatistic {
#         int book_id PK
#         string(8) stat_ymd PK
#         int rent_count
#         int rating_sum
#         int rating_count
#         date stat_date
#     }
#     MemberStatistic {
#         string(20) member_id PK
#         string(8) stat_ymd PK
#         int rent_count
#         int rating_sum
#         int rating_count
#         date stat_date
#     }
#     BookCategory ||..o{ BookCategory : ""
#     BookCategory ||..o{ Book : ""
#     Book ||--o{ BookStock : ""
#     BookStock ||--o{ Rent : ""
#     Member ||--o{ Rent : ""
#     Member ||--o{ Rating : ""
#     Book ||--o{ Rating : ""
#     Book ||--o{ BookTag : ""
#     Book ||--|| BookDetail : ""
#     Tag ||--o{ BookTag : ""
#     Book ||--o{ Review : ""
#     Member ||--o{ Review : ""
# ```
